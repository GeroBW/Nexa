# %%
import requests
import json

url = 'http://localhost:9000/admin/products'
headers = {
    'Accept': 'application/json',
    'Authorization': 'Basic sk_45c33dd9e514a5f5fa352c15f34c157cf8933d5e85766c9b5aaf02bed86564bf',
    'Cookie': 'connect.sid=s%3Ax3N4d3Wu7NlCoZ9rZUmtUWZl40PaUvDI.FSrcQ71fahEmZWEU0dMqE0a5mdeGagiy4fUJ2qMDR%2FY'
}

response = requests.get(url, headers=headers)
products = response.json()
# print(json.dumps(products, indent=4))
products
filtered_products = [product for product in products['products'] if 'localhost' not in product['thumbnail']]
filtered_products
# Out:
# [{'id': 'prod_01JJJVQGM231CWEVX523S60BYB',
#   'title': 'Hemd Monaco - 72 cm Armlänge',
#   'subtitle': None,
#   'status': 'published',
#   'external_id': None,
#   'description': '<div class="woocommerce-product-details__short-description">\n\\n<p>Unser Hemd Monaco – jetzt nur noch ein wenig Sonne, und man fühlt sich damit wie an der Côte d’Azur. Ein toller Stoff aus Baumwolle und Leinen. Sehr lässig, und zugleich elegant. Auf der Strandpromenade, an der Bar, aber auch im Büro und Home Office – dieses Hemd weiß zu begeistern. Kleine Details wie die farblich abstimmten Knöpfe und der “geheime” Steg zum Hochkrempeln der Ärmel geben diesem Hemd das gewisse Etwas.</p>\n\\n<p>Perfekt für sehr große Männer - in Überlänge, und mit 72 cm langen Ärmeln.</p>\n\\n</div>\n\\n<p>In den Paßformen <span class="a-text-bold">Slim Fit</span> und in <span class="a-text-bold">Modern Fit</span> erhältlich.</p>',
#   'handle': 'hemd-monaco-72-cm-armlange',
#   'is_giftcard': False,
# ...

# %%
for product in filtered_products:
    product_id = product['id']
    delete_url = f"{url}/{product_id}"
    response = requests.delete(delete_url, headers=headers)
    if response.status_code == 200:
        print(f"Deleted product ID: {product_id}")
    else:
        print(f"Failed to delete product ID: {product_id}, Status Code: {response.status_code}")
# Out:
# Deleted product ID: prod_01JJJVQGM231CWEVX523S60BYB
# Deleted product ID: prod_01JJJVQGM2BTPN8G1P1CYH8NZJ
# Deleted product ID: prod_01JJJVQGM2C468K41AJ71FMR2E
# Deleted product ID: prod_01JJJVQGM2F9DY8VK8HDGGT8JE
# Deleted product ID: prod_01JJJVQGM2FPXRE9MQS84396T4
# Deleted product ID: prod_01JJJVQGM2J2SJRAFEFKCGCKJ7
# Deleted product ID: prod_01JJJVQGM2JWN3QC60CGNQMQ5H
# Deleted product ID: prod_01JJJVQGM2N1CDBQB84C7TMC6V
# Deleted product ID: prod_01JJJVQGM2NJ5GBJ8QZQT58CFF
# Deleted product ID: prod_01JJJVQGM2STYB8CTVGBEHV4DP
# Deleted product ID: prod_01JJJVQGM2TQ9C6B2436TCH56A
# Deleted product ID: prod_01JJJVQGM2X0J2EZP67HQAH2ES
# Deleted product ID: prod_01JJJVQGM2X85HPTFGAGH1CA6V
# Deleted product ID: prod_01JJJVQGM2XHSM4PZ4Z0JH3K00
